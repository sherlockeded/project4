# %%
import tensorflow as tf
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('/home/iris/Desktop/target1/MNIST_data')
# Out:
# WARNING:tensorflow:From /home/iris/anaconda3/envs/venv/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /home/iris/Desktop/target1/MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/iris/anaconda3/envs/venv/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /home/iris/Desktop/target1/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting /home/iris/Desktop/target1/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting /home/iris/Desktop/target1/MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/iris/anaconda3/envs/venv/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
def get_inputs(real_size, noise_size):
    """
    真实图像tensor与噪声图像tensor
    """
    real_img = tf.placeholder(tf.float32, [None, real_size], name='real_img')
    noise_img = tf.placeholder(tf.float32, [None, noise_size], name='noise_img')
    
    return real_img, noise_img

# %%
def get_generator(noise_img, n_units, out_dim, reuse=False, alpha=0.01):
    """
    生成器
    
    noise_img: 生成器的输入
    n_units: 隐层单元个数
    out_dim: 生成器输出tensor的size，这里应该为32*32=784
    alpha: leaky ReLU系数
    """
    with tf.variable_scope("generator", reuse=reuse):
        # hidden layer
        hidden1 = tf.layers.dense(noise_img, n_units)
        # leaky ReLU
        hidden1 = tf.maximum(alpha * hidden1, hidden1)
        # dropout
        hidden1 = tf.layers.dropout(hidden1, rate=0.2)

        # logits & outputs
        logits = tf.layers.dense(hidden1, out_dim)
        outputs = tf.tanh(logits)
        
        return logits, outputs

# %%
def get_discriminator(img, n_units, reuse=False, alpha=0.01):
    """
    判别器
    
    n_units: 隐层结点数量
    alpha: Leaky ReLU系数
    """
    
    with tf.variable_scope("discriminator", reuse=reuse):
        # hidden layer
        hidden1 = tf.layers.dense(img, n_units)
        hidden1 = tf.maximum(alpha * hidden1, hidden1)
        
        # logits & outputs
        logits = tf.layers.dense(hidden1, 1)
        outputs = tf.sigmoid(logits)
        
        return logits, outputs

# %%
# 定义参数
# 真实图像的size
img_size = mnist.train.images[0].shape[0]
print(mnist.train.images.shape)
# 传入给generator的噪声size
noise_size = 100
# 生成器隐层参数
g_units = 128
# 判别器隐层参数
d_units = 128
# leaky ReLU的参数
alpha = 0.01
# learning_rate
learning_rate = 0.001
# label smoothing
smooth = 0.1
# Out:
# (55000, 784)

# %%
tf.reset_default_graph()

real_img, noise_img = get_inputs(img_size, noise_size)

# generator
g_logits, g_outputs = get_generator(noise_img, g_units, img_size)

# discriminator
d_logits_real, d_outputs_real = get_discriminator(real_img, d_units)
d_logits_fake, d_outputs_fake = get_discriminator(g_outputs, d_units, reuse=True)

# %%
# discriminator的loss
# 识别真实图片
d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                                     labels=tf.ones_like(d_logits_real)) * (1 - smooth))
# 识别生成的图片
d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                                     labels=tf.zeros_like(d_logits_fake)))
# 总体loss
d_loss = tf.add(d_loss_real, d_loss_fake)

# generator的loss
g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                                labels=tf.ones_like(d_logits_fake)) * (1 - smooth))

# %%
train_vars = tf.trainable_variables()

# generator中的tensor
g_vars = [var for var in train_vars if var.name.startswith("generator")]
# discriminator中的tensor
d_vars = [var for var in train_vars if var.name.startswith("discriminator")]

# optimizer
d_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(d_loss, var_list=d_vars)
g_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(g_loss, var_list=g_vars)

# %%
# batch_size
batch_size = 64
# 训练迭代轮数
epochs = 300
# 抽取样本数
n_sample = 25

# 存储测试样例
samples = []
# 存储loss
losses = []
# 保存生成器变量
saver = tf.train.Saver(var_list = g_vars)
# 开始训练
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for batch_i in range(mnist.train.num_examples//batch_size):
            batch = mnist.train.next_batch(batch_size)
            
            batch_images = batch[0].reshape((batch_size, 784))
            # 对图像像素进行scale，这是因为tanh输出的结果介于(-1,1),real和fake图片共享discriminator的参数
            batch_images = batch_images*2 - 1
            
            # generator的输入噪声
            batch_noise = np.random.uniform(-1, 1, size=(batch_size, noise_size))
            
            # Run optimizers
            _ = sess.run(d_train_opt, feed_dict={real_img: batch_images, noise_img: batch_noise})
            _ = sess.run(g_train_opt, feed_dict={noise_img: batch_noise})
        
        # 每一轮结束计算loss
        train_loss_d = sess.run(d_loss, 
                                feed_dict = {real_img: batch_images, 
                                             noise_img: batch_noise})
        # real img loss
        train_loss_d_real = sess.run(d_loss_real, 
                                     feed_dict = {real_img: batch_images, 
                                                 noise_img: batch_noise})
        # fake img loss
        train_loss_d_fake = sess.run(d_loss_fake, 
                                    feed_dict = {real_img: batch_images, 
                                                 noise_img: batch_noise})
        # generator loss
        train_loss_g = sess.run(g_loss, 
                                feed_dict = {noise_img: batch_noise})
        
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}(Real: {:.4f} + Fake: {:.4f})...".format(train_loss_d, train_loss_d_real, train_loss_d_fake),
              "Generator Loss: {:.4f}".format(train_loss_g))    
        # 记录各类loss值
        losses.append((train_loss_d, train_loss_d_real, train_loss_d_fake, train_loss_g))
        
        # 抽取样本后期进行观察
        sample_noise = np.random.uniform(-1, 1, size=(n_sample, noise_size))
        gen_samples = sess.run(get_generator(noise_img, g_units, img_size, reuse=True),
                               feed_dict={noise_img: sample_noise})
        samples.append(gen_samples)
        
        # 存储checkpoints
        saver.save(sess, './checkpoints/mygenerator.ckpt')

# 将sample的生成数据记录下来
with open('train_samples.pkl', 'wb') as f:
    pickle.dump(samples, f)
# Out:
# Epoch 1/300... Discriminator Loss: 0.0249(Real: 0.0018 + Fake: 0.0231)... Generator Loss: 4.1175
# Epoch 2/300... Discriminator Loss: 1.0881(Real: 0.5861 + Fake: 0.5020)... Generator Loss: 4.5976
# Epoch 3/300... Discriminator Loss: 0.6074(Real: 0.3519 + Fake: 0.2555)... Generator Loss: 6.7859
# Epoch 4/300... Discriminator Loss: 1.7064(Real: 0.7594 + Fake: 0.9470)... Generator Loss: 0.8508
# Epoch 5/300... Discriminator Loss: 1.8433(Real: 0.7162 + Fake: 1.1272)... Generator Loss: 0.9593
# Epoch 6/300... Discriminator Loss: 2.1340(Real: 0.8480 + Fake: 1.2860)... Generator Loss: 1.2583
# Epoch 7/300... Discriminator Loss: 0.6911(Real: 0.4386 + Fake: 0.2526)... Generator Loss: 2.0338
# Epoch 8/300... Discriminator Loss: 1.7347(Real: 0.7371 + Fake: 0.9976)... Generator Loss: 2.3748
# Epoch 9/300... Discriminator Loss: 1.1985(Real: 0.8333 + Fake: 0.3652)... Generator Loss: 1.6852
# Epoch 10/300... Discriminator Loss: 1.6661(Real: 1.0476 + Fake: 0.6184)... Generator Loss: 1.2439
# Epoch 11/300... Discriminator Loss: 0.8586(Real: 0.4053 + Fake: 0.4533)... Generator Loss: 1.8086
# Epoch 12/300... Discriminator Loss: 1.3928(Real: 0.7285 + Fake: 0.6642)... Generator Loss: 1.7494
# Epoch 13/300... Discriminator Loss: 0.6324(Real: 0.4818 + Fake: 0.1506)... Generator Loss: 2.4855
# Epoch 14/300... Discriminator Loss: 1.2562(Real: 0.5212 + Fake: 0.7350)... Generator Loss: 1.1442
# Epoch 15/300... Discriminator Loss: 1.3224(Real: 0.7638 + Fake: 0.5586)... Generator Loss: 1.8459
# Epoch 16/300... Discriminator Loss: 1.0227(Real: 0.3122 + Fake: 0.7105)... Generator Loss: 1.0497
# Epoch 17/300... Discriminator Loss: 1.5920(Real: 0.6366 + Fake: 0.9554)... Generator Loss: 0.8639
# Epoch 18/300... Discriminator Loss: 0.8320(Real: 0.5372 + Fake: 0.2949)... Generator Loss: 2.0184
# Epoch 19/300... Discriminator Loss: 1.4841(Real: 0.6250 + Fake: 0.8591)... Generator Loss: 0.9790
# Epoch 20/300... Discriminator Loss: 0.9879(Real: 0.7224 + Fake: 0.2656)... Generator Loss: 1.9703
# Epoch 21/300... Discriminator Loss: 1.2631(Real: 0.8109 + Fake: 0.4521)... Generator Loss: 1.9419
# Epoch 22/300... Discriminator Loss: 0.8447(Real: 0.3905 + Fake: 0.4542)... Generator Loss: 1.7263
# Epoch 23/300... Discriminator Loss: 0.7059(Real: 0.5042 + Fake: 0.2017)... Generator Loss: 2.7834
# Epoch 24/300... Discriminator Loss: 0.8961(Real: 0.4926 + Fake: 0.4034)... Generator Loss: 1.3105
# Epoch 25/300... Discriminator Loss: 1.1043(Real: 0.8253 + Fake: 0.2789)... Generator Loss: 1.9171
# Epoch 26/300... Discriminator Loss: 0.8146(Real: 0.3387 + Fake: 0.4759)... Generator Loss: 1.7493
# Epoch 27/300... Discriminator Loss: 0.7057(Real: 0.3472 + Fake: 0.3585)... Generator Loss: 1.6749
# Epoch 28/300... Discriminator Loss: 0.8948(Real: 0.6023 + Fake: 0.2925)... Generator Loss: 2.2011
# Epoch 29/300... Discriminator Loss: 0.8482(Real: 0.3732 + Fake: 0.4750)... Generator Loss: 1.5999
# Epoch 30/300... Discriminator Loss: 0.7828(Real: 0.4373 + Fake: 0.3455)... Generator Loss: 1.6943
# Epoch 31/300... Discriminator Loss: 0.9469(Real: 0.5915 + Fake: 0.3553)... Generator Loss: 2.0940
# Epoch 32/300... Discriminator Loss: 0.7266(Real: 0.4133 + Fake: 0.3133)... Generator Loss: 1.8087
# Epoch 33/300... Discriminator Loss: 1.1313(Real: 0.5581 + Fake: 0.5731)... Generator Loss: 1.4300
# Epoch 34/300... Discriminator Loss: 0.9552(Real: 0.4122 + Fake: 0.5430)... Generator Loss: 1.4304
# Epoch 35/300... Discriminator Loss: 1.1200(Real: 0.4173 + Fake: 0.7028)... Generator Loss: 1.1823
# Epoch 36/300... Discriminator Loss: 0.9972(Real: 0.5977 + Fake: 0.3995)... Generator Loss: 1.6467
# Epoch 37/300... Discriminator Loss: 1.0585(Real: 0.4872 + Fake: 0.5713)... Generator Loss: 1.2690
# Epoch 38/300... Discriminator Loss: 1.0779(Real: 0.4307 + Fake: 0.6473)... Generator Loss: 1.1850
# Epoch 39/300... Discriminator Loss: 1.0814(Real: 0.4447 + Fake: 0.6367)... Generator Loss: 1.2628
# Epoch 40/300... Discriminator Loss: 1.2767(Real: 0.6212 + Fake: 0.6555)... Generator Loss: 1.2234
# Epoch 41/300... Discriminator Loss: 0.8464(Real: 0.4384 + Fake: 0.4081)... Generator Loss: 1.5271
# Epoch 42/300... Discriminator Loss: 1.0336(Real: 0.4036 + Fake: 0.6300)... Generator Loss: 1.2346
# Epoch 43/300... Discriminator Loss: 1.1463(Real: 0.4625 + Fake: 0.6838)... Generator Loss: 1.0263
# Epoch 44/300... Discriminator Loss: 1.0507(Real: 0.6793 + Fake: 0.3713)... Generator Loss: 1.7507
# Epoch 45/300... Discriminator Loss: 0.9927(Real: 0.2485 + Fake: 0.7442)... Generator Loss: 1.1687
# Epoch 46/300... Discriminator Loss: 1.1819(Real: 0.5959 + Fake: 0.5859)... Generator Loss: 1.2231
# Epoch 47/300... Discriminator Loss: 0.9472(Real: 0.6850 + Fake: 0.2622)... Generator Loss: 1.8224
# Epoch 48/300... Discriminator Loss: 0.9773(Real: 0.4267 + Fake: 0.5507)... Generator Loss: 1.4263
# Epoch 49/300... Discriminator Loss: 0.9674(Real: 0.4889 + Fake: 0.4785)... Generator Loss: 1.5014
# Epoch 50/300... Discriminator Loss: 1.2425(Real: 0.5837 + Fake: 0.6588)... Generator Loss: 1.1836
# Epoch 51/300... Discriminator Loss: 0.7881(Real: 0.3704 + Fake: 0.4176)... Generator Loss: 1.6160
# Epoch 52/300... Discriminator Loss: 0.9408(Real: 0.4786 + Fake: 0.4622)... Generator Loss: 1.5031
# Epoch 53/300... Discriminator Loss: 0.9077(Real: 0.4259 + Fake: 0.4818)... Generator Loss: 1.5762
# Epoch 54/300... Discriminator Loss: 0.9098(Real: 0.5488 + Fake: 0.3610)... Generator Loss: 1.8423
# Epoch 55/300... Discriminator Loss: 0.9046(Real: 0.3005 + Fake: 0.6041)... Generator Loss: 1.2998
# Epoch 56/300... Discriminator Loss: 0.6888(Real: 0.4200 + Fake: 0.2688)... Generator Loss: 1.6539
# Epoch 57/300... Discriminator Loss: 0.9325(Real: 0.3552 + Fake: 0.5774)... Generator Loss: 1.1190
# Epoch 58/300... Discriminator Loss: 0.8746(Real: 0.4356 + Fake: 0.4390)... Generator Loss: 1.4690
# Epoch 59/300... Discriminator Loss: 0.8811(Real: 0.4280 + Fake: 0.4531)... Generator Loss: 1.4944
# Epoch 60/300... Discriminator Loss: 0.9299(Real: 0.5354 + Fake: 0.3945)... Generator Loss: 1.5113
# Epoch 61/300... Discriminator Loss: 0.7593(Real: 0.2849 + Fake: 0.4744)... Generator Loss: 1.2578
# Epoch 62/300... Discriminator Loss: 1.0709(Real: 0.5336 + Fake: 0.5372)... Generator Loss: 1.1653
# Epoch 63/300... Discriminator Loss: 1.0011(Real: 0.5473 + Fake: 0.4538)... Generator Loss: 1.2999
# Epoch 64/300... Discriminator Loss: 1.0892(Real: 0.4888 + Fake: 0.6004)... Generator Loss: 1.2730
# Epoch 65/300... Discriminator Loss: 1.1511(Real: 0.5241 + Fake: 0.6270)... Generator Loss: 1.1066
# Epoch 66/300... Discriminator Loss: 0.8750(Real: 0.6104 + Fake: 0.2646)... Generator Loss: 1.8728
# Epoch 67/300... Discriminator Loss: 0.9787(Real: 0.3992 + Fake: 0.5796)... Generator Loss: 1.1247
# Epoch 68/300... Discriminator Loss: 0.6616(Real: 0.3762 + Fake: 0.2855)... Generator Loss: 1.7157
# Epoch 69/300... Discriminator Loss: 0.9718(Real: 0.6244 + Fake: 0.3474)... Generator Loss: 1.5487
# Epoch 70/300... Discriminator Loss: 0.8855(Real: 0.4819 + Fake: 0.4036)... Generator Loss: 1.7001
# Epoch 71/300... Discriminator Loss: 0.8334(Real: 0.3727 + Fake: 0.4608)... Generator Loss: 1.2567
# Epoch 72/300... Discriminator Loss: 1.1417(Real: 0.7087 + Fake: 0.4329)... Generator Loss: 1.5460
# Epoch 73/300... Discriminator Loss: 0.7738(Real: 0.4801 + Fake: 0.2936)... Generator Loss: 1.7528
# Epoch 74/300... Discriminator Loss: 1.0540(Real: 0.6476 + Fake: 0.4064)... Generator Loss: 1.5544
# Epoch 75/300... Discriminator Loss: 1.1001(Real: 0.5337 + Fake: 0.5663)... Generator Loss: 1.3107
# Epoch 76/300... Discriminator Loss: 0.8704(Real: 0.5609 + Fake: 0.3094)... Generator Loss: 1.7316
# Epoch 77/300... Discriminator Loss: 1.0082(Real: 0.4654 + Fake: 0.5427)... Generator Loss: 1.2919
# Epoch 78/300... Discriminator Loss: 0.9241(Real: 0.4346 + Fake: 0.4896)... Generator Loss: 1.2386
# Epoch 79/300... Discriminator Loss: 0.8821(Real: 0.3392 + Fake: 0.5430)... Generator Loss: 1.3537
# Epoch 80/300... Discriminator Loss: 0.8234(Real: 0.4353 + Fake: 0.3880)... Generator Loss: 1.6204
# Epoch 81/300... Discriminator Loss: 0.8509(Real: 0.4583 + Fake: 0.3926)... Generator Loss: 1.3389
# Epoch 82/300... Discriminator Loss: 0.9527(Real: 0.3282 + Fake: 0.6245)... Generator Loss: 1.0663
# Epoch 83/300... Discriminator Loss: 0.6586(Real: 0.3900 + Fake: 0.2686)... Generator Loss: 1.8124
# Epoch 84/300... Discriminator Loss: 0.8432(Real: 0.5320 + Fake: 0.3112)... Generator Loss: 1.7904
# Epoch 85/300... Discriminator Loss: 0.8445(Real: 0.4257 + Fake: 0.4188)... Generator Loss: 1.4212
# Epoch 86/300... Discriminator Loss: 0.9723(Real: 0.5027 + Fake: 0.4696)... Generator Loss: 1.2986
# Epoch 87/300... Discriminator Loss: 0.9179(Real: 0.5216 + Fake: 0.3963)... Generator Loss: 1.4519
# Epoch 88/300... Discriminator Loss: 0.9823(Real: 0.4760 + Fake: 0.5063)... Generator Loss: 1.4674
# Epoch 89/300... Discriminator Loss: 0.9030(Real: 0.5342 + Fake: 0.3688)... Generator Loss: 1.8965
# Epoch 90/300... Discriminator Loss: 0.7316(Real: 0.4258 + Fake: 0.3058)... Generator Loss: 1.8777
# Epoch 91/300... Discriminator Loss: 1.1140(Real: 0.4522 + Fake: 0.6618)... Generator Loss: 1.0315
# Epoch 92/300... Discriminator Loss: 1.0095(Real: 0.5645 + Fake: 0.4450)... Generator Loss: 1.4486
# Epoch 93/300... Discriminator Loss: 0.8669(Real: 0.5205 + Fake: 0.3464)... Generator Loss: 1.5960
# Epoch 94/300... Discriminator Loss: 0.9859(Real: 0.6100 + Fake: 0.3758)... Generator Loss: 1.4657
# Epoch 95/300... Discriminator Loss: 1.0770(Real: 0.5516 + Fake: 0.5254)... Generator Loss: 1.3146
# Epoch 96/300... Discriminator Loss: 0.9167(Real: 0.3925 + Fake: 0.5242)... Generator Loss: 1.2329
# Epoch 97/300... Discriminator Loss: 0.8564(Real: 0.4715 + Fake: 0.3849)... Generator Loss: 1.4873
# Epoch 98/300... Discriminator Loss: 1.0013(Real: 0.5712 + Fake: 0.4301)... Generator Loss: 1.3553
# Epoch 99/300... Discriminator Loss: 1.0610(Real: 0.4408 + Fake: 0.6202)... Generator Loss: 1.1497
# Epoch 100/300... Discriminator Loss: 0.8790(Real: 0.4762 + Fake: 0.4029)... Generator Loss: 1.6051
# Epoch 101/300... Discriminator Loss: 0.8847(Real: 0.4640 + Fake: 0.4207)... Generator Loss: 1.5847
# Epoch 102/300... Discriminator Loss: 0.8219(Real: 0.4487 + Fake: 0.3732)... Generator Loss: 1.7192
# Epoch 103/300... Discriminator Loss: 0.7924(Real: 0.4880 + Fake: 0.3044)... Generator Loss: 1.7914
# Epoch 104/300... Discriminator Loss: 1.0363(Real: 0.4444 + Fake: 0.5919)... Generator Loss: 1.2596
# Epoch 105/300... Discriminator Loss: 0.7883(Real: 0.4034 + Fake: 0.3849)... Generator Loss: 1.6143
# Epoch 106/300... Discriminator Loss: 0.8951(Real: 0.4356 + Fake: 0.4595)... Generator Loss: 1.4207
# Epoch 107/300... Discriminator Loss: 0.9157(Real: 0.5383 + Fake: 0.3774)... Generator Loss: 1.6017
# Epoch 108/300... Discriminator Loss: 0.8600(Real: 0.3453 + Fake: 0.5147)... Generator Loss: 1.2856
# Epoch 109/300... Discriminator Loss: 0.9838(Real: 0.4709 + Fake: 0.5129)... Generator Loss: 1.3364
# Epoch 110/300... Discriminator Loss: 0.7890(Real: 0.4672 + Fake: 0.3217)... Generator Loss: 1.7689
# Epoch 111/300... Discriminator Loss: 0.9237(Real: 0.5950 + Fake: 0.3287)... Generator Loss: 1.6329
# Epoch 112/300... Discriminator Loss: 0.8103(Real: 0.4433 + Fake: 0.3670)... Generator Loss: 1.4229
# Epoch 113/300... Discriminator Loss: 0.7847(Real: 0.3438 + Fake: 0.4409)... Generator Loss: 1.3327
# Epoch 114/300... Discriminator Loss: 1.1537(Real: 0.5855 + Fake: 0.5682)... Generator Loss: 1.1791
# Epoch 115/300... Discriminator Loss: 0.9357(Real: 0.3303 + Fake: 0.6054)... Generator Loss: 1.2140
# Epoch 116/300... Discriminator Loss: 0.9229(Real: 0.5783 + Fake: 0.3446)... Generator Loss: 1.7406
# Epoch 117/300... Discriminator Loss: 1.0391(Real: 0.4497 + Fake: 0.5894)... Generator Loss: 1.2160
# Epoch 118/300... Discriminator Loss: 0.8409(Real: 0.4326 + Fake: 0.4082)... Generator Loss: 1.5641
# Epoch 119/300... Discriminator Loss: 1.0788(Real: 0.6269 + Fake: 0.4519)... Generator Loss: 1.3716
# Epoch 120/300... Discriminator Loss: 0.8228(Real: 0.4198 + Fake: 0.4030)... Generator Loss: 1.5874
# Epoch 121/300... Discriminator Loss: 0.9477(Real: 0.4088 + Fake: 0.5389)... Generator Loss: 1.2168
# Epoch 122/300... Discriminator Loss: 0.8460(Real: 0.3676 + Fake: 0.4784)... Generator Loss: 1.3260
# Epoch 123/300... Discriminator Loss: 0.8810(Real: 0.4161 + Fake: 0.4649)... Generator Loss: 1.5054
# Epoch 124/300... Discriminator Loss: 0.7200(Real: 0.3510 + Fake: 0.3689)... Generator Loss: 1.6678
# Epoch 125/300... Discriminator Loss: 0.7614(Real: 0.3730 + Fake: 0.3884)... Generator Loss: 1.4460
# Epoch 126/300... Discriminator Loss: 1.0614(Real: 0.3741 + Fake: 0.6872)... Generator Loss: 1.0990
# Epoch 127/300... Discriminator Loss: 0.9518(Real: 0.6018 + Fake: 0.3500)... Generator Loss: 1.5610
# Epoch 128/300... Discriminator Loss: 0.8387(Real: 0.5016 + Fake: 0.3371)... Generator Loss: 1.7292
# Epoch 129/300... Discriminator Loss: 0.8088(Real: 0.4032 + Fake: 0.4056)... Generator Loss: 1.4331
# Epoch 130/300... Discriminator Loss: 1.0547(Real: 0.6737 + Fake: 0.3810)... Generator Loss: 1.6326
# Epoch 131/300... Discriminator Loss: 0.9566(Real: 0.4970 + Fake: 0.4596)... Generator Loss: 1.4591
# Epoch 132/300... Discriminator Loss: 0.7426(Real: 0.3545 + Fake: 0.3881)... Generator Loss: 1.5158
# Epoch 133/300... Discriminator Loss: 0.9736(Real: 0.4278 + Fake: 0.5458)... Generator Loss: 1.1291
# Epoch 134/300... Discriminator Loss: 0.9557(Real: 0.5182 + Fake: 0.4375)... Generator Loss: 1.4154
# Epoch 135/300... Discriminator Loss: 0.8162(Real: 0.4045 + Fake: 0.4117)... Generator Loss: 1.5837
# Epoch 136/300... Discriminator Loss: 0.7827(Real: 0.3286 + Fake: 0.4541)... Generator Loss: 1.3966
# Epoch 137/300... Discriminator Loss: 0.8605(Real: 0.4852 + Fake: 0.3754)... Generator Loss: 1.5765
# Epoch 138/300... Discriminator Loss: 0.9122(Real: 0.3230 + Fake: 0.5892)... Generator Loss: 1.0946
# Epoch 139/300... Discriminator Loss: 1.0114(Real: 0.4251 + Fake: 0.5863)... Generator Loss: 1.1458
# Epoch 140/300... Discriminator Loss: 1.0063(Real: 0.3686 + Fake: 0.6378)... Generator Loss: 1.1759
# Epoch 141/300... Discriminator Loss: 0.7793(Real: 0.3140 + Fake: 0.4653)... Generator Loss: 1.4735
# Epoch 142/300... Discriminator Loss: 0.7930(Real: 0.3846 + Fake: 0.4084)... Generator Loss: 1.5955
# Epoch 143/300... Discriminator Loss: 0.8329(Real: 0.4853 + Fake: 0.3477)... Generator Loss: 1.7325
# Epoch 144/300... Discriminator Loss: 0.7769(Real: 0.3165 + Fake: 0.4604)... Generator Loss: 1.3584
# Epoch 145/300... Discriminator Loss: 0.9361(Real: 0.4291 + Fake: 0.5070)... Generator Loss: 1.2242
# Epoch 146/300... Discriminator Loss: 1.0083(Real: 0.4028 + Fake: 0.6055)... Generator Loss: 1.2312
# Epoch 147/300... Discriminator Loss: 0.8781(Real: 0.4449 + Fake: 0.4332)... Generator Loss: 1.4855
# Epoch 148/300... Discriminator Loss: 1.0556(Real: 0.3228 + Fake: 0.7328)... Generator Loss: 1.0092
# Epoch 149/300... Discriminator Loss: 1.0023(Real: 0.6562 + Fake: 0.3461)... Generator Loss: 1.6643
# Epoch 150/300... Discriminator Loss: 0.8737(Real: 0.4764 + Fake: 0.3973)... Generator Loss: 1.5490
# Epoch 151/300... Discriminator Loss: 0.7818(Real: 0.4247 + Fake: 0.3571)... Generator Loss: 1.5671
# Epoch 152/300... Discriminator Loss: 0.9802(Real: 0.5547 + Fake: 0.4255)... Generator Loss: 1.4506
# Epoch 153/300... Discriminator Loss: 0.8637(Real: 0.2949 + Fake: 0.5688)... Generator Loss: 1.1985
# Epoch 154/300... Discriminator Loss: 0.9474(Real: 0.4459 + Fake: 0.5015)... Generator Loss: 1.2894
# Epoch 155/300... Discriminator Loss: 0.8285(Real: 0.2912 + Fake: 0.5373)... Generator Loss: 1.2507
# Epoch 156/300... Discriminator Loss: 1.0478(Real: 0.5092 + Fake: 0.5387)... Generator Loss: 1.1566
# Epoch 157/300... Discriminator Loss: 0.6982(Real: 0.3246 + Fake: 0.3736)... Generator Loss: 1.4446
# Epoch 158/300... Discriminator Loss: 0.9659(Real: 0.4594 + Fake: 0.5065)... Generator Loss: 1.2971
# Epoch 159/300... Discriminator Loss: 1.0276(Real: 0.3523 + Fake: 0.6753)... Generator Loss: 1.1597
# Epoch 160/300... Discriminator Loss: 1.0830(Real: 0.5723 + Fake: 0.5107)... Generator Loss: 1.4181
# Epoch 161/300... Discriminator Loss: 0.8685(Real: 0.4035 + Fake: 0.4651)... Generator Loss: 1.2733
# Epoch 162/300... Discriminator Loss: 0.9094(Real: 0.4596 + Fake: 0.4498)... Generator Loss: 1.4503
# Epoch 163/300... Discriminator Loss: 0.9420(Real: 0.5645 + Fake: 0.3775)... Generator Loss: 1.5902
# Epoch 164/300... Discriminator Loss: 0.9532(Real: 0.5823 + Fake: 0.3708)... Generator Loss: 1.8416
# Epoch 165/300... Discriminator Loss: 0.9986(Real: 0.6679 + Fake: 0.3307)... Generator Loss: 1.6758
# Epoch 166/300... Discriminator Loss: 0.8456(Real: 0.5288 + Fake: 0.3168)... Generator Loss: 1.7457
# Epoch 167/300... Discriminator Loss: 0.8731(Real: 0.4234 + Fake: 0.4497)... Generator Loss: 1.3742
# Epoch 168/300... Discriminator Loss: 0.8267(Real: 0.3619 + Fake: 0.4648)... Generator Loss: 1.3162
# Epoch 169/300... Discriminator Loss: 1.0711(Real: 0.4957 + Fake: 0.5755)... Generator Loss: 1.2036
# Epoch 170/300... Discriminator Loss: 0.9877(Real: 0.4161 + Fake: 0.5716)... Generator Loss: 1.2263
# Epoch 171/300... Discriminator Loss: 1.0510(Real: 0.5429 + Fake: 0.5081)... Generator Loss: 1.2981
# Epoch 172/300... Discriminator Loss: 0.8482(Real: 0.4754 + Fake: 0.3729)... Generator Loss: 1.6902
# Epoch 173/300... Discriminator Loss: 0.7940(Real: 0.3861 + Fake: 0.4079)... Generator Loss: 1.4552
# Epoch 174/300... Discriminator Loss: 1.2018(Real: 0.5412 + Fake: 0.6606)... Generator Loss: 1.1338
# Epoch 175/300... Discriminator Loss: 0.8304(Real: 0.4618 + Fake: 0.3686)... Generator Loss: 1.5290
# Epoch 176/300... Discriminator Loss: 0.6495(Real: 0.2480 + Fake: 0.4014)... Generator Loss: 1.6022
# Epoch 177/300... Discriminator Loss: 0.9493(Real: 0.5027 + Fake: 0.4465)... Generator Loss: 1.4770
# Epoch 178/300... Discriminator Loss: 0.8721(Real: 0.4165 + Fake: 0.4556)... Generator Loss: 1.4359
# Epoch 179/300... Discriminator Loss: 0.8929(Real: 0.5709 + Fake: 0.3220)... Generator Loss: 1.6763
# Epoch 180/300... Discriminator Loss: 0.8005(Real: 0.3085 + Fake: 0.4920)... Generator Loss: 1.3079
# Epoch 181/300... Discriminator Loss: 0.9455(Real: 0.4188 + Fake: 0.5267)... Generator Loss: 1.2433
# Epoch 182/300... Discriminator Loss: 0.9373(Real: 0.4520 + Fake: 0.4853)... Generator Loss: 1.4564
# Epoch 183/300... Discriminator Loss: 0.8092(Real: 0.3507 + Fake: 0.4586)... Generator Loss: 1.5707
# Epoch 184/300... Discriminator Loss: 0.9363(Real: 0.4191 + Fake: 0.5171)... Generator Loss: 1.2852
# Epoch 185/300... Discriminator Loss: 0.8871(Real: 0.4649 + Fake: 0.4222)... Generator Loss: 1.5767
# Epoch 186/300... Discriminator Loss: 0.9684(Real: 0.4603 + Fake: 0.5082)... Generator Loss: 1.3148
# Epoch 187/300... Discriminator Loss: 1.0307(Real: 0.6588 + Fake: 0.3719)... Generator Loss: 1.7081
# Epoch 188/300... Discriminator Loss: 0.8351(Real: 0.4164 + Fake: 0.4187)... Generator Loss: 1.5295
# Epoch 189/300... Discriminator Loss: 0.9573(Real: 0.4280 + Fake: 0.5293)... Generator Loss: 1.3237
# Epoch 190/300... Discriminator Loss: 0.8613(Real: 0.4946 + Fake: 0.3667)... Generator Loss: 1.6632
# Epoch 191/300... Discriminator Loss: 0.8012(Real: 0.2994 + Fake: 0.5018)... Generator Loss: 1.3827
# Epoch 192/300... Discriminator Loss: 0.8807(Real: 0.4251 + Fake: 0.4557)... Generator Loss: 1.4668
# Epoch 193/300... Discriminator Loss: 0.8805(Real: 0.4939 + Fake: 0.3866)... Generator Loss: 1.4735
# Epoch 194/300... Discriminator Loss: 1.0550(Real: 0.5266 + Fake: 0.5284)... Generator Loss: 1.4338
# Epoch 195/300... Discriminator Loss: 0.9370(Real: 0.4825 + Fake: 0.4544)... Generator Loss: 1.4326
# Epoch 196/300... Discriminator Loss: 0.9389(Real: 0.5823 + Fake: 0.3566)... Generator Loss: 1.5203
# Epoch 197/300... Discriminator Loss: 0.8681(Real: 0.2642 + Fake: 0.6040)... Generator Loss: 1.1312
# Epoch 198/300... Discriminator Loss: 0.9744(Real: 0.4699 + Fake: 0.5045)... Generator Loss: 1.4464
# Epoch 199/300... Discriminator Loss: 0.8588(Real: 0.4237 + Fake: 0.4350)... Generator Loss: 1.5034
# Epoch 200/300... Discriminator Loss: 0.8650(Real: 0.4837 + Fake: 0.3813)... Generator Loss: 1.5724
# Epoch 201/300... Discriminator Loss: 0.7167(Real: 0.4608 + Fake: 0.2559)... Generator Loss: 1.9050
# Epoch 202/300... Discriminator Loss: 0.8637(Real: 0.4187 + Fake: 0.4451)... Generator Loss: 1.3388
# Epoch 203/300... Discriminator Loss: 1.0950(Real: 0.3429 + Fake: 0.7521)... Generator Loss: 1.0481
# Epoch 204/300... Discriminator Loss: 0.7934(Real: 0.4857 + Fake: 0.3077)... Generator Loss: 1.7653
# Epoch 205/300... Discriminator Loss: 0.9785(Real: 0.4959 + Fake: 0.4826)... Generator Loss: 1.3654
# Epoch 206/300... Discriminator Loss: 0.9849(Real: 0.3552 + Fake: 0.6297)... Generator Loss: 1.1207
# Epoch 207/300... Discriminator Loss: 0.9630(Real: 0.4132 + Fake: 0.5497)... Generator Loss: 1.2298
# Epoch 208/300... Discriminator Loss: 0.9396(Real: 0.4355 + Fake: 0.5040)... Generator Loss: 1.3088
# Epoch 209/300... Discriminator Loss: 0.8534(Real: 0.3379 + Fake: 0.5155)... Generator Loss: 1.3793
# Epoch 210/300... Discriminator Loss: 0.7342(Real: 0.4287 + Fake: 0.3055)... Generator Loss: 1.7173
# Epoch 211/300... Discriminator Loss: 0.9837(Real: 0.6387 + Fake: 0.3450)... Generator Loss: 1.7281
# Epoch 212/300... Discriminator Loss: 1.0625(Real: 0.5424 + Fake: 0.5201)... Generator Loss: 1.3240
# Epoch 213/300... Discriminator Loss: 1.0200(Real: 0.6293 + Fake: 0.3908)... Generator Loss: 1.5958
# Epoch 214/300... Discriminator Loss: 0.9685(Real: 0.5289 + Fake: 0.4396)... Generator Loss: 1.4328
# Epoch 215/300... Discriminator Loss: 0.8576(Real: 0.3109 + Fake: 0.5467)... Generator Loss: 1.3577
# Epoch 216/300... Discriminator Loss: 0.8933(Real: 0.3702 + Fake: 0.5231)... Generator Loss: 1.2012
# Epoch 217/300... Discriminator Loss: 0.9981(Real: 0.5210 + Fake: 0.4770)... Generator Loss: 1.4369
# Epoch 218/300... Discriminator Loss: 0.8950(Real: 0.4978 + Fake: 0.3972)... Generator Loss: 1.5622
# Epoch 219/300... Discriminator Loss: 0.9697(Real: 0.4900 + Fake: 0.4797)... Generator Loss: 1.5271
# Epoch 220/300... Discriminator Loss: 1.0244(Real: 0.3447 + Fake: 0.6798)... Generator Loss: 0.9855
# Epoch 221/300... Discriminator Loss: 0.9147(Real: 0.4736 + Fake: 0.4412)... Generator Loss: 1.4167
# Epoch 222/300... Discriminator Loss: 0.8079(Real: 0.4363 + Fake: 0.3716)... Generator Loss: 1.6637
# Epoch 223/300... Discriminator Loss: 1.0512(Real: 0.6554 + Fake: 0.3957)... Generator Loss: 1.5855
# Epoch 224/300... Discriminator Loss: 0.8413(Real: 0.5164 + Fake: 0.3249)... Generator Loss: 1.7012
# Epoch 225/300... Discriminator Loss: 0.8730(Real: 0.4043 + Fake: 0.4686)... Generator Loss: 1.3917
# Epoch 226/300... Discriminator Loss: 0.8672(Real: 0.3982 + Fake: 0.4690)... Generator Loss: 1.4363
# Epoch 227/300... Discriminator Loss: 0.9198(Real: 0.4685 + Fake: 0.4513)... Generator Loss: 1.4559
# Epoch 228/300... Discriminator Loss: 0.8122(Real: 0.3573 + Fake: 0.4549)... Generator Loss: 1.4161
# Epoch 229/300... Discriminator Loss: 0.8874(Real: 0.5628 + Fake: 0.3246)... Generator Loss: 1.7908
# Epoch 230/300... Discriminator Loss: 0.8796(Real: 0.5052 + Fake: 0.3744)... Generator Loss: 1.6132
# Epoch 231/300... Discriminator Loss: 0.8139(Real: 0.4912 + Fake: 0.3227)... Generator Loss: 1.8465
# Epoch 232/300... Discriminator Loss: 0.6980(Real: 0.3917 + Fake: 0.3063)... Generator Loss: 1.6949
# Epoch 233/300... Discriminator Loss: 0.9726(Real: 0.4094 + Fake: 0.5632)... Generator Loss: 1.1804
# Epoch 234/300... Discriminator Loss: 0.9183(Real: 0.3692 + Fake: 0.5491)... Generator Loss: 1.2975
# Epoch 235/300... Discriminator Loss: 0.8105(Real: 0.4548 + Fake: 0.3557)... Generator Loss: 1.6098
# Epoch 236/300... Discriminator Loss: 1.0134(Real: 0.4643 + Fake: 0.5491)... Generator Loss: 1.3977
# Epoch 237/300... Discriminator Loss: 1.0267(Real: 0.4577 + Fake: 0.5690)... Generator Loss: 1.3950
# Epoch 238/300... Discriminator Loss: 0.9516(Real: 0.4284 + Fake: 0.5232)... Generator Loss: 1.4030
# Epoch 239/300... Discriminator Loss: 1.1321(Real: 0.6005 + Fake: 0.5316)... Generator Loss: 1.3150
# Epoch 240/300... Discriminator Loss: 0.9298(Real: 0.4386 + Fake: 0.4911)... Generator Loss: 1.4139
# Epoch 241/300... Discriminator Loss: 0.9398(Real: 0.5465 + Fake: 0.3933)... Generator Loss: 1.4857
# Epoch 242/300... Discriminator Loss: 0.9828(Real: 0.5387 + Fake: 0.4441)... Generator Loss: 1.5021
# Epoch 243/300... Discriminator Loss: 0.8819(Real: 0.4245 + Fake: 0.4574)... Generator Loss: 1.4269
# Epoch 244/300... Discriminator Loss: 0.9725(Real: 0.6770 + Fake: 0.2955)... Generator Loss: 1.9118
# Epoch 245/300... Discriminator Loss: 0.9695(Real: 0.4372 + Fake: 0.5323)... Generator Loss: 1.3003
# Epoch 246/300... Discriminator Loss: 0.8277(Real: 0.2680 + Fake: 0.5598)... Generator Loss: 1.1440
# Epoch 247/300... Discriminator Loss: 1.0518(Real: 0.6367 + Fake: 0.4151)... Generator Loss: 1.5728
# Epoch 248/300... Discriminator Loss: 0.8408(Real: 0.5631 + Fake: 0.2776)... Generator Loss: 1.7902
# Epoch 249/300... Discriminator Loss: 0.9766(Real: 0.5854 + Fake: 0.3912)... Generator Loss: 1.5071
# Epoch 250/300... Discriminator Loss: 1.0363(Real: 0.5817 + Fake: 0.4546)... Generator Loss: 1.6388
# Epoch 251/300... Discriminator Loss: 1.0071(Real: 0.6543 + Fake: 0.3528)... Generator Loss: 1.5503
# Epoch 252/300... Discriminator Loss: 0.8889(Real: 0.4943 + Fake: 0.3946)... Generator Loss: 1.4317
# Epoch 253/300... Discriminator Loss: 0.8291(Real: 0.5433 + Fake: 0.2858)... Generator Loss: 1.8757
# Epoch 254/300... Discriminator Loss: 0.8572(Real: 0.5245 + Fake: 0.3326)... Generator Loss: 1.5793
# Epoch 255/300... Discriminator Loss: 0.8019(Real: 0.4235 + Fake: 0.3784)... Generator Loss: 1.4482
# Epoch 256/300... Discriminator Loss: 0.9993(Real: 0.5362 + Fake: 0.4632)... Generator Loss: 1.5397
# Epoch 257/300... Discriminator Loss: 0.8365(Real: 0.4209 + Fake: 0.4155)... Generator Loss: 1.4261
# Epoch 258/300... Discriminator Loss: 0.7637(Real: 0.4155 + Fake: 0.3482)... Generator Loss: 1.5342
# Epoch 259/300... Discriminator Loss: 0.7992(Real: 0.4348 + Fake: 0.3644)... Generator Loss: 1.6828
# Epoch 260/300... Discriminator Loss: 0.8517(Real: 0.4214 + Fake: 0.4303)... Generator Loss: 1.5060
# Epoch 261/300... Discriminator Loss: 0.9779(Real: 0.3863 + Fake: 0.5916)... Generator Loss: 1.3861
# Epoch 262/300... Discriminator Loss: 0.8101(Real: 0.5131 + Fake: 0.2970)... Generator Loss: 1.9072
# Epoch 263/300... Discriminator Loss: 0.7046(Real: 0.4044 + Fake: 0.3002)... Generator Loss: 1.6693
# Epoch 264/300... Discriminator Loss: 0.8316(Real: 0.5026 + Fake: 0.3290)... Generator Loss: 1.6521
# Epoch 265/300... Discriminator Loss: 1.0035(Real: 0.6451 + Fake: 0.3584)... Generator Loss: 1.6308
# Epoch 266/300... Discriminator Loss: 1.0506(Real: 0.6836 + Fake: 0.3670)... Generator Loss: 1.5574
# Epoch 267/300... Discriminator Loss: 0.9229(Real: 0.4922 + Fake: 0.4307)... Generator Loss: 1.4978
# Epoch 268/300... Discriminator Loss: 0.9091(Real: 0.5058 + Fake: 0.4034)... Generator Loss: 1.5901
# Epoch 269/300... Discriminator Loss: 0.7763(Real: 0.2963 + Fake: 0.4800)... Generator Loss: 1.3242
# Epoch 270/300... Discriminator Loss: 0.8617(Real: 0.4135 + Fake: 0.4482)... Generator Loss: 1.4607
# Epoch 271/300... Discriminator Loss: 0.9476(Real: 0.3877 + Fake: 0.5599)... Generator Loss: 1.2921
# Epoch 272/300... Discriminator Loss: 0.9116(Real: 0.5121 + Fake: 0.3994)... Generator Loss: 1.4499
# Epoch 273/300... Discriminator Loss: 0.7696(Real: 0.4746 + Fake: 0.2950)... Generator Loss: 1.9288
# Epoch 274/300... Discriminator Loss: 0.9834(Real: 0.4684 + Fake: 0.5150)... Generator Loss: 1.3527
# Epoch 275/300... Discriminator Loss: 0.9459(Real: 0.4893 + Fake: 0.4565)... Generator Loss: 1.5040
# Epoch 276/300... Discriminator Loss: 0.9662(Real: 0.4558 + Fake: 0.5104)... Generator Loss: 1.2007
# Epoch 277/300... Discriminator Loss: 0.6875(Real: 0.3692 + Fake: 0.3183)... Generator Loss: 1.5975
# Epoch 278/300... Discriminator Loss: 0.8645(Real: 0.4152 + Fake: 0.4493)... Generator Loss: 1.5000
# Epoch 279/300... Discriminator Loss: 0.9311(Real: 0.5402 + Fake: 0.3909)... Generator Loss: 1.6369
# Epoch 280/300... Discriminator Loss: 0.8937(Real: 0.4583 + Fake: 0.4353)... Generator Loss: 1.4756
# Epoch 281/300... Discriminator Loss: 0.9203(Real: 0.3793 + Fake: 0.5410)... Generator Loss: 1.2285
# Epoch 282/300... Discriminator Loss: 0.8630(Real: 0.3960 + Fake: 0.4670)... Generator Loss: 1.4069
# Epoch 283/300... Discriminator Loss: 0.8006(Real: 0.3076 + Fake: 0.4930)... Generator Loss: 1.2280
# Epoch 284/300... Discriminator Loss: 0.6136(Real: 0.3413 + Fake: 0.2723)... Generator Loss: 1.8132
# Epoch 285/300... Discriminator Loss: 0.9179(Real: 0.2470 + Fake: 0.6709)... Generator Loss: 1.1306
# Epoch 286/300... Discriminator Loss: 0.9942(Real: 0.6366 + Fake: 0.3575)... Generator Loss: 1.6882
# Epoch 287/300... Discriminator Loss: 1.0632(Real: 0.5221 + Fake: 0.5411)... Generator Loss: 1.3840
# Epoch 288/300... Discriminator Loss: 1.0593(Real: 0.5246 + Fake: 0.5347)... Generator Loss: 1.3479
# Epoch 289/300... Discriminator Loss: 0.9301(Real: 0.3033 + Fake: 0.6268)... Generator Loss: 1.0272
# Epoch 290/300... Discriminator Loss: 0.8401(Real: 0.4074 + Fake: 0.4327)... Generator Loss: 1.6052
# Epoch 291/300... Discriminator Loss: 0.8919(Real: 0.4260 + Fake: 0.4659)... Generator Loss: 1.3800
# Epoch 292/300... Discriminator Loss: 0.8993(Real: 0.5240 + Fake: 0.3753)... Generator Loss: 1.6174
# Epoch 293/300... Discriminator Loss: 0.9790(Real: 0.4333 + Fake: 0.5457)... Generator Loss: 1.3485
# Epoch 294/300... Discriminator Loss: 1.0222(Real: 0.5815 + Fake: 0.4408)... Generator Loss: 1.3250
# Epoch 295/300... Discriminator Loss: 0.9009(Real: 0.5281 + Fake: 0.3728)... Generator Loss: 1.6188
# Epoch 296/300... Discriminator Loss: 0.9768(Real: 0.4290 + Fake: 0.5479)... Generator Loss: 1.5317
# Epoch 297/300... Discriminator Loss: 0.9127(Real: 0.4436 + Fake: 0.4691)... Generator Loss: 1.3808
# Epoch 298/300... Discriminator Loss: 0.9571(Real: 0.2818 + Fake: 0.6753)... Generator Loss: 0.9463
# Epoch 299/300... Discriminator Loss: 0.9968(Real: 0.4257 + Fake: 0.5711)... Generator Loss: 1.2945
# Epoch 300/300... Discriminator Loss: 1.0486(Real: 0.4967 + Fake: 0.5519)... Generator Loss: 1.0967

# %%
fig, ax = plt.subplots(figsize=(20,7))
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator Total Loss')
plt.plot(losses.T[1], label='Discriminator Real Loss')
plt.plot(losses.T[2], label='Discriminator Fake Loss')
plt.plot(losses.T[3], label='Generator')
plt.title("Training Losses")
plt.legend()

# %%
# Load samples from generator taken while training

with open('train_samples.pkl', 'rb') as f:
    samples = pickle.load(f)

# %%
def view_samples(epoch, samples):
    """
    epoch代表第几次迭代的图像
    samples为我们的采样结果
    """
    fig, axes = plt.subplots(figsize=(7,7), nrows=5, ncols=5, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch][1]): # 这里samples[epoch][1]代表生成的图像结果，而[0]代表对应的logits
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
_ = view_samples(-1, samples) # 显示最后一轮的outputs

# %%
# 指定要查看的轮次
epoch_idx = [0, 5, 10, 20, 40, 60, 80, 100, 150, 250] 
show_imgs = []
for i in epoch_idx:
    show_imgs.append(samples[i][1])

# %%
# 指定图片形状
rows, cols = 10, 25
fig, axes = plt.subplots(figsize=(30,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

idx = range(0, epochs, int(epochs/rows))

for sample, ax_row in zip(show_imgs, axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %%
# 加载我们的生成器变量
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    sample_noise = np.random.uniform(-1, 1, size=(25, noise_size))
    gen_samples = sess.run(get_generator(noise_img, g_units, img_size, reuse=True),
                           feed_dict={noise_img: sample_noise})
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/mygenerator.ckpt

# %%
_ = view_samples(0, [gen_samples])
